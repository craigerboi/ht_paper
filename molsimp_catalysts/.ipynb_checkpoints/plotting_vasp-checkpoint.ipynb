# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import re
import pickle
from matplotlib.patches import Ellipse
from matplotlib.lines import Line2D
import math
import matplotlib.patches as mpatches

from collections import defaultdict
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
def get_ens(outcar):
    errs = []
    
    with open(outcar, "r") as f:
        lines = f.readlines()
    
    for idx, line in enumerate(lines):
        if "BEEFens" in line:
            relevant_idx = idx+1
    for line in lines[relevant_idx:relevant_idx+2000]:
        errs.append(float(line))
    return np.asarray(errs)

h2_ens = get_ens("/home/michael/ref_beef_calcs/H2/OUTCAR")
h2o_ens = get_ens("/home/michael/ref_beef_calcs/H2O/OUTCAR")

finished_outcars = pickle.load(open("/home/michael/PycharmProjects/gaussian_job_manage/finished_vasps.p", "rb"))

finished_vacs = finished_outcars[::3]
finished_ohs = finished_outcars[1::3]
finished_oohs = finished_outcars[2::3]

bad_catalysts = ["Ni_32a_32", "Ni_3a1_10", "Co_3a1_9_", "Fe_31a_11", "Ni_oct_desorbed_4_", "Co_31a_9_" 
                "Cr_32a_33", "Cr_32a_35", "Co_3a1_11", "Ni_31a_9_", "Co_3a1_7_", "Cr_31a_16", "Fe_3a1_11",
                "Cr_3a1_27", "Fe_31a_9_", "Mn_31a_12", "Ni_31a_11", "Ni_31a_10", "Mn_3a1_18", "Cr_3a1_16", 
                 "Mn_3a1_15", "Cr_31a_17", "Cr_32a_33", "Cr_3a1_3_", "Cr_31a_8_", "Cr_3a1_9_", "Cr_3a1_8_"]

catalyst2ens_errors = defaultdict(float)
catalyst2angles = defaultdict(float)
catalyst2ratio = defaultdict(float)
catalys2oh_ens = defaultdict()
catalys2ooh_ens = defaultdict()
for v, oh, ooh in zip(finished_vacs, finished_ohs, finished_oohs):    
    if "lorbit_add" in v:
        name = v.split("/")[4]
    else:
        name = v.split("/")[5]
    if name in bad_catalysts or "penta" in name:
        continue
    catname = v.split("/")[5]
    vac_ens = get_ens(v)
    oh_ens = get_ens(oh)
    ooh_ens = get_ens(ooh)
    
    oh_err = np.std(oh_ens-vac_ens-h2o_ens+0.5*h2_ens)
    ooh_err = np.std(ooh_ens-vac_ens-2*h2o_ens+1.5*h2_ens)
    total_oh_ens = oh_ens-vac_ens-h2o_ens+0.5*h2_ens
    total_ooh_ens = ooh_ens-vac_ens-2*h2o_ens+1.5*h2_ens
    
    within_range_ooh = []
    within_range_oh = []
    for idx, x in enumerate(total_ooh_ens):
        if abs(x)<ooh_err and total_oh_ens[idx]<oh_err:
            within_range_ooh.append(x)
            within_range_oh.append(total_oh_ens[idx])
    catalys2oh_ens[catname] = within_range_oh
    catalys2ooh_ens[catname] = within_range_ooh

# %%
finished_vacs
# Out:
# ['/home/michael/beef_molsimps/beef_molsimps/Fe_31a_17/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_23/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_32a_35/VAC/HS/back/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_32a_35/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_32a_34/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_23/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_5_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_5_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_28/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_17/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_1_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_22/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_penta_4/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_24/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_2_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_30/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_25/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_32a_35/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_penta_5/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_14/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_28/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_32a_35/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_24/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_penta_2/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_18/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_20/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_6_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_16/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_oct_desorbed_2_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_32a_31/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_4_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_19/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_15/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_32a_34/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_3_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_oct_desorbed_5_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_17/VAC/HS/forw/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_4_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_13/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_27/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_32a_31/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_20/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_20/VAC/HS/forw/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_41a_2_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_26/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_penta_1/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_10/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_penta_1/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_25/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_22/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_24/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_29/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_22/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_20/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_30/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_penta_3/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_28/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_15/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_16/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_24/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_oct_desorbed_4_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_5_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_2_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_oct_desorbed_4_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_26/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_penta_1/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_oct_desorbed_6_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_oct_desorbed_5_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_17/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_oct_desorbed_4_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_oct_desorbed_5_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_17/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_29/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_1_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_21/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_10/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_23/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_29/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_41a_2_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_penta_4/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_10/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_5_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_4_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_23/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_32a_32/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_oct_desorbed_5_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_17/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_24/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_7_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_41a_1_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_28/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_oct_desorbed_3_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_20/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_penta_2/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_1_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_5_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_32a_32/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_2_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_oct_desorbed_2_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_20/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_25/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_oct_desorbed_6_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_15/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_26/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_oct_desorbed_4_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_17/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_28/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_32a_33/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_oct_desorbed_2_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_9_/VAC/HS/lorbit_test/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_oct_desorbed_2_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_32a_32/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_18/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_oct_desorbed_1_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_26/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_10/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_5_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_oct_desorbed_3_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_32a_34/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_pbp_5_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_23/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_10/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_3a1_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_5_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_32a_34/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_penta_5/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_32a_35/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_11/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_penta_2/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_penta_4/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_41a_3_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_32a_35/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_30/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_30/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_30/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_6_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_32a_33/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_11/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_41a_2_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_3_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_29/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_8_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_32a_31/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_3a1_20/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_32a_34/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_23/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_12/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_1_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_29/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_3a1_28/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_7_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_2_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_oct_desorbed_2_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_9_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_12/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_20/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_penta_1/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_14/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_3a1_26/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_oct_desorbed_5_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_30/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_23/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_penta_1/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_28/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_30/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_31a_26/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_20/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_24/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_3_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_oct_desorbed_6_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_9_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_25/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_24/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_29/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_3_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_29/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_19/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_9_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_27/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Fe_31a_18/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_27/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_13/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_3a1_2_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_31a_8_/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_26/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_penta_3/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_9_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_14/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_24/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_32a_31/VAC/HS/forw/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ni_31a_13/VAC/LS/ispin2/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_4_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_4_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_13/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_26/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_5_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_28/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_oct_desorbed_3_/VAC/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_penta_2/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_4_/VAC/HS/forw/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Cr_3a1_8_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_31a_18/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_9_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_26/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_3a1_22/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_41a_3_/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Mn_32a_31/VAC/HS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_31a_16/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Ru_3a1_19/VAC/LS/OUTCAR',
#  '/home/michael/beef_molsimps/beef_molsimps/Co_oct_desorbed_1_/VAC/HS/OUTCAR']

# %%
charged_cats = []
for v in finished_vacs:
    with open(v.replace("OUTCAR", "INCAR"), "r") as f:
        lines = f.readlines()
    
    for line in lines:
        if "NELECT" in line:
            find = True
            charged_cats.append(v.split("/")[5])
            break

# %%
label2metal = {
    "#404040": "Cr",
    "#4CC3D9": "Co",
    "#7BC8A4": "Ni",
    "#FFC65D": "Mn",
    "#93648D": "Ru", 
    "#F16745": "Fe"
}

# %%
from matplotlib.patches import Patch, Circle
custom_lgd = [
    Line2D(range(1), range(1),label='Cr',marker='o', color='#404040', lw=0, markersize=12, alpha=0.75),
    Line2D(range(1), range(1),label='Ru',marker='o', color='#93648D', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1), label='Co',marker='o', color='#4CC3D9', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1),label='Fe',marker='o', color='#F16745', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1),label='Mn',marker='o', color='#FFC65D', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1),label='Ni',marker='o', color='#7BC8A4', lw=0, markersize=12,alpha=0.75),
]

fig, ax = plt.subplots(figsize=(12,9))

ele2color = {
    "Fe": "#F16745",
    "Co": "#4CC3D9",
    "Mn": "#FFC65D",
    "Cr": "#404040",
    "Ru": "#93648D",
    "Ni": "#7BC8A4"
}

geom2shape = {
    "31a": "D",
    "3a1": "^",
    "oct_desorbed": "o",
    "32a": "P",
    "hexa": "v",
    "41a": "H"
}

data = pickle.load(open("/home/michael/PycharmProjects/gaussian_job_manage/vasp_data.p", 'rb'))

catnames = []
oh_values = []
ooh_values = []

for name in data:
    if "pbp" in name or "penta" in name:
        continue
    if name in bad_catalysts:
        continue
        
    catnames.append(name)
    oh_values.append(data[name][0])
    ooh_values.append(data[name][1])

sns.regplot(oh_values, ooh_values, scatter_kws={'color':'w'})
for name, oh_val, ooh_val in zip(catnames, oh_values, ooh_values):

    color = ele2color[name[:2]]
    for key in geom2shape:
        if key in name:
            marker = geom2shape[key]

    plt.plot(oh_val, ooh_val, alpha=0.5, color=color, marker=marker, markersize=10)
    
#plt.axis('equal')
from scipy.stats import linregress
print(linregress(oh_values, ooh_values))
plt.plot(1.23, 3.69, marker='*')
ax.legend(handles=custom_lgd, fontsize=18)
plt.xlabel("$\Delta{G_{HO*}}$ (eV)", fontsize=16)
plt.ylabel("$\Delta{G_{HOO*}}$ (eV)", fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
print(len(oh_values))
plt.savefig("nochg_beef_data.pdf")
# Out:
# LinregressResult(slope=0.9088650834783357, intercept=3.288163973633774, rvalue=0.9679808195005462, pvalue=1.1678014151562137e-66, stderr=0.022679648866866523)
# 110

# %%
import matplotlib.tri as tri

metal_to_x_vec = defaultdict(list)
metal_to_y_vec = defaultdict(list)

for name, oh_val, ooh_val in zip(catnames, oh_values, ooh_values):
    #plt.plot(np.asaray(catalys2oh_ens[name])+oh_val, np.asarray(catalys2ooh_ens[name])+ooh_val,
    metal_to_x_vec[name[:2]].append(list(np.asarray(catalys2oh_ens[name])+oh_val)[:1000])
    metal_to_y_vec[name[:2]].append(list(np.asarray(catalys2ooh_ens[name])+ooh_val)[:1000])

for key in metal_to_x_vec:
    metal_to_x_vec[key] = [x for y in metal_to_x_vec[key] for  x in y]
    metal_to_y_vec[key] = [x for y in metal_to_y_vec[key] for  x in y]

# %%
label2metal = {
    "#404040": "Cr",
    "#4CC3D9": "Co",
    "#7BC8A4": "Ni",
    "#FFC65D": "Mn",
    "#93648D": "Ru", 
    "#F16745": "Fe"
}

from matplotlib.legend_handler import HandlerPatch
colors = ["g", "w"]
texts = ["Green Data Description", "RedData Description"]
class HandlerEllipse(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        center = 0.5 * width - 0.5 * xdescent, 0.5 * height - 0.5 * ydescent
        p = mpatches.Ellipse(xy=center, width=height + xdescent,
                             height=height + ydescent)
        self.update_prop(p, orig_handle, legend)
        p.set_transform(trans)
        return [p]

metals = ["Cr", "Co", "Ni", "Mn", "Ru", "Fe"]
c = [ mpatches.Circle((0.5, 0.5), radius=0.25, facecolor=ele2color[i], edgecolor="none" ) for i in metals]
#plt.legend(c,texts, ncol=2, handler_map={mpatches.Circle: HandlerEllipse()})

# %%
count= 0
for n in catnames:
    if "Co" in n:
        count+=1
        print(n)
        
print(count)
# Out:
# Co_3a1_17
# Co_31a_30
# Co_31a_14
# Co_32a_35
# Co_oct_desorbed_2_
# Co_3a1_30
# Co_31a_15
# Co_oct_desorbed_4_
# Co_oct_desorbed_6_
# Co_oct_desorbed_5_
# Co_3a1_29
# Co_3a1_10
# Co_31a_17
# Co_41a_1_
# Co_oct_desorbed_3_
# Co_32a_32
# Co_3a1_25
# Co_32a_33
# Co_41a_2_
# Co_31a_9_
# Co_3a1_27
# Co_3a1_13
# Co_31a_26
# Co_31a_18
# Co_3a1_26
# Co_oct_desorbed_1_
# 26

# %%
import matplotlib.patches as mpatches

c = [ mpatches.Circle((0.5, 0.5), 1, facecolor=ele2color[i], linewidth=3, label=i) for i in metals]

# custom_lgd = [
#     Circle((0.5, 0.5), 1, label='Co', color='#4CC3D9'),
#     Circle((0.5, 0.5), 1,label='Fe', color='#F16745'),
#     Circle((0.5, 0.5), 1,label='Ru', color='#93648D'),
#     Circle((0.5, 0.5), 1,label='Ni', color='#7BC8A4'),
#     Circle((0.5, 0.5), 1,label='Mn', color='#FFC65D'),
#     Circle((0.5, 0.5), 1,label='Cr', color='#404040'),

# ]
custom_lgd = [
    Line2D(range(1), range(1),label='Cr',marker='o', color='#404040', lw=0, markersize=12, alpha=0.75),
    Line2D(range(1), range(1),label='Ru',marker='o', color='#93648D', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1), label='Co',marker='o', color='#4CC3D9', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1),label='Fe',marker='o', color='#F16745', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1),label='Mn',marker='o', color='#FFC65D', lw=0, markersize=12,alpha=0.75),
    Line2D(range(1), range(1),label='Ni',marker='o', color='#7BC8A4', lw=0, markersize=12,alpha=0.75),


]

def multivariateGrid(col_x, col_y, col_k, df, k_is_color=False, scatter_alpha=.005, scatter_size=0.25):
    def colored_scatter(x, y, c=None):
        def scatter(*args, **kwargs):
            args = (x, y)
            if c is not None:
                kwargs['c'] = c
            kwargs['alpha'] = scatter_alpha
            kwargs['s'] = scatter_size
            kwargs['label'] = label2metal[c]
            plt.scatter(*args, **kwargs)
            plt.ylabel("$\Delta{G_{HOO*}}$ (eV)", fontsize=15)
            plt.xlabel("$\Delta{G_{HO*}}$ (eV)", fontsize=15)
            plt.xticks(fontsize=13)
            plt.yticks(fontsize=13)

        return scatter

    g = sns.JointGrid(
        x=col_x,
        y=col_y,
        data=df,
        height=8, ratio=4, space=0.
    )
    color = None
    legends=[]
    for name, df_group in df.groupby(col_k):
        legends.append(name)
        if k_is_color:
            color=name
        g.plot_joint(
            colored_scatter(df_group[col_x],df_group[col_y],color),
        )
        sns.distplot(
            df_group[col_x].values,
            ax=g.ax_marg_x,
            color=color,
            norm_hist=False, 
            kde=False,
            bins=100
        )
        sns.distplot(
            df_group[col_y].values,
            ax=g.ax_marg_y,
            color=color,            
            vertical=True,
            norm_hist=False,
            kde=False, 
            bins=100
        )
    #plt.legend(c, metals,ncol=6, handler_map={mpatches.Circle: HandlerEllipse()}, fontsize=18).get_frame().set_facecolor('#F1F7EE')
    plt.legend(handles=custom_lgd, fontsize=13, ncol=6, handletextpad=0.0000001, loc='upper left')
    
import pandas as pd

cr_df = pd.DataFrame()
ru_df = pd.DataFrame()

cr_df['$\Delta{G_{HO*}}$ (eV)'] = metal_to_x_vec['Cr']
cr_df['$\Delta{G_{HOO*}}$ (eV)'] = metal_to_y_vec['Cr']
cr_df['metal'] = '#404040'
ru_df['$\Delta{G_{HO*}}$ (eV)'] = metal_to_x_vec['Ru']
ru_df['$\Delta{G_{HOO*}}$ (eV)'] = metal_to_y_vec['Ru']
ru_df['metal'] = '#93648D'

together_df = cr_df.append(ru_df).append(pd.DataFrame({
    "$\Delta{G_{HO*}}$ (eV)": metal_to_x_vec['Fe'],
    "$\Delta{G_{HOO*}}$ (eV)": metal_to_y_vec['Fe'],
    "metal": "#F16745"
})).append(pd.DataFrame({
    "$\Delta{G_{HO*}}$ (eV)": metal_to_x_vec['Ni'],
    "$\Delta{G_{HOO*}}$ (eV)": metal_to_y_vec['Ni'],
    "metal": "#7BC8A4"}
)).append(pd.DataFrame({
    "$\Delta{G_{HO*}}$ (eV)": metal_to_x_vec['Co'],
    "$\Delta{G_{HOO*}}$ (eV)": metal_to_y_vec['Co'],
    "metal": "#4CC3D9"}
)).append(pd.DataFrame({
    "$\Delta{G_{HO*}}$ (eV)": metal_to_x_vec['Mn'],
    "$\Delta{G_{HOO*}}$ (eV)": metal_to_y_vec['Mn'],
    "metal": "#FFC65D"
}))


image = multivariateGrid('$\Delta{G_{HO*}}$ (eV)', '$\Delta{G_{HOO*}}$ (eV)', 'metal', df=together_df,
                 k_is_color=True, scatter_alpha=.75, scatter_size=0.01)
plt.xlabel("$\Delta{G_{HO*}}$ (eV)", fontsize=16)
plt.ylabel("$\Delta{G_{HOO*}}$ (eV)", fontsize=16)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)

plt.savefig("alltogether.pdf")
plt.savefig("alltogether.png", dpi=800)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-e032056c4a0a> in <module>
#     107
#     108 image = multivariateGrid('$\Delta{G_{HO*}}$ (eV)', '$\Delta{G_{HOO*}}$ (eV)', 'metal', df=together_df,
# --> 109                  k_is_color=True, scatter_alpha=.75, scatter_size=0.01)
#     110 plt.xlabel("$\Delta{G_{HO*}}$ (eV)", fontsize=16)
#     111 plt.ylabel("$\Delta{G_{HOO*}}$ (eV)", fontsize=16)
#
# <ipython-input-25-e032056c4a0a> in multivariateGrid(col_x, col_y, col_k, df, k_is_color, scatter_alpha, scatter_size)
#      53             color=name
#      54         g.plot_joint(
# ---> 55             colored_scatter(df_group[col_x],df_group[col_y],color),
#      56         )
#      57         sns.distplot(
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py in plot_joint(self, func, **kwargs)
#    1782         """
#    1783         plt.sca(self.ax_joint)
# -> 1784         func(self.x, self.y, **kwargs)
#    1785
#    1786         return self
#
# <ipython-input-25-e032056c4a0a> in scatter(*args, **kwargs)
#      32             kwargs['s'] = scatter_size
#      33             kwargs['label'] = label2metal[c]
# ---> 34             plt.scatter(*args, **kwargs)
#      35             plt.ylabel("$\Delta{G_{HOO*}}$ (eV)", fontsize=15)
#      36             plt.xlabel("$\Delta{G_{HO*}}$ (eV)", fontsize=15)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4496                 offsets=offsets,
#    4497                 transOffset=kwargs.pop('transform', self.transData),
# -> 4498                 alpha=alpha
#    4499                 )
#    4500         collection.set_transform(mtransforms.IdentityTransform())
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, paths, sizes, **kwargs)
#     881         """
#     882
# --> 883         Collection.__init__(self, **kwargs)
#     884         self.set_paths(paths)
#     885         self.set_sizes(sizes)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     149         self._uniform_offsets = None
#     150         if offsets is not None:
# --> 151             offsets = np.asanyarray(offsets, float)
#     152             # Broadcast (2,) -> (1, 2) but nothing else.
#     153             if offsets.shape == (2,):
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asanyarray(a, dtype, order)
#     136
#     137     """
# --> 138     return array(a, dtype, copy=False, order=order, subok=True)
#     139
#     140
#
# ValueError: setting an array element with a sequence.

# %%
from scipy.stats import linregress
sns.regplot(together_df["$\Delta{G_{HO*}}$ (eV)"], together_df["$\Delta{G_{HOO*}}$ (eV)"], 
            scatter_kws={'alpha': 0.01})
print(linregress(together_df["$\Delta{G_{HO*}}$ (eV)"], together_df["$\Delta{G_{HOO*}}$ (eV)"]))
# Out:
# LinregressResult(slope=0.9415229149433358, intercept=3.275693634341298, rvalue=0.9491082417931805, pvalue=0.0, stderr=0.0007111815019208133)

# %%
import seaborn as sns

sns.kdeplot(metal_to_x_vec["Ni"], metal_to_y_vec["Ni"], color='g', 
            shade=True, bw=0.025, shade_lowest=False, alpha=0.1)

# %%
from scipy.stats import linregress
metals = ['Cr', 'Mn', 'Fe', 'Co', 'Ni', 'Ru']
for m in metals:
    sns.regplot(oh_values, ooh_values, scatter_kws={'color':'w'})
    
    sns.kdeplot(metal_to_x_vec[m], metal_to_y_vec[m], color=ele2color[m], shade=True, label=m,
                 shade_lowest=False, alpha=0.5)
    plt.plot(1.23, 3.69, marker='*')
    ax.legend(handles=custom_lgd, fontsize=18)
    #plt.xlabel("$\Delta{G_{HO*}}$")
    plt.savefig("beef_data_{}.pdf".format(m))
    print(linregress(metal_to_x_vec[m], metal_to_y_vec[m]))
    plt.show()
# Out:
# LinregressResult(slope=1.1631033498624057, intercept=3.3961816527297732, rvalue=0.9427214090134579, pvalue=0.0, stderr=0.00237623950825066)
# LinregressResult(slope=1.0768082604559217, intercept=3.280505888021638, rvalue=0.8993172602044833, pvalue=0.0, stderr=0.004139700040021937)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-29842ec81c5f> in <module>
#      10     #plt.xlabel("$\Delta{G_{HO*}}$")
#      11     plt.savefig("beef_data_{}.pdf".format(m))
# ---> 12     print(linregress(metal_to_x_vec[m], metal_to_y_vec[m]))
#      13     plt.show()
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/stats/_stats_mstats_common.py in linregress(x, y)
#     103             raise ValueError(msg)
#     104     else:
# --> 105         x = np.asarray(x)
#     106         y = np.asarray(y)
#     107
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# KeyboardInterrupt:

# %%
from scipy.stats import linregress
print(linregress(oh_values, ooh_values))

# %%
for name in data:
    if "Fe_pen" in name:
        print(name)
        print(data[name])

# %%
for name, oh in zip(catnames, oh_values):
    if "Fe" in name:
        print(name, oh)

# %%
dist1 = oh_ens-vac_ens-h2o_ens+0.5*h2_ens
dist2 = ooh_ens-vac_ens-2*h2o_ens+1.5*h2_ens

err_matr = np.zeros(shape=(2000,2))
count = 0
for val1, val2 in zip(dist1, dist2):
    err_matr[count][0] = val1
    err_matr[count][1] = val2
