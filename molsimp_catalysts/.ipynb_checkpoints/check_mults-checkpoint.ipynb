# %%
import matplotlib.pyplot as plt
import numpy as np
from ase import io
import re
from mpl_toolkits import mplot3d
from collections import defaultdict
# %matplotlib inline
# %matplotlib notebook

# %%
import pickle

logs = pickle.load(open("/home/michael/PycharmProjects/gaussian_job_manage/complete_logs.p", "rb"))

bad_catalysts = ["Ni_32a_32", "Ni_3a1_10", "Co_3a1_9_", "Fe_31a_11", "Ni_oct_desorbed_4_", "Co_31a_9_" 
                "Cr_32a_33", "Cr_32a_35", "Co_3a1_11", "Ni_31a_9_", "Co_3a1_7_", "Cr_31a_16", "Fe_3a1_11",
                "Cr_3a1_27", "Fe_31a_9_", "Mn_31a_12", "Ni_31a_11", "Ni_31a_10", "Mn_3a1_18", "Cr_3a1_16", 
                 "Mn_3a1_15", "Cr_31a_17", "Cr_32a_33", "Cr_3a1_3_", "Cr_31a_8_", "Cr_3a1_9_", "Cr_3a1_8_"]

logs = [x for x in logs if "/OOH/" in x and x.split("/")[4] not in bad_catalysts]
oh_logs = [x for x in logs if "/OH/" in x and x.split("/")[4] not in bad_catalysts]

# %%
def get_spin_dens(log):
    structure = io.read(log, format='gaussian-out')
    with open(log, "r") as f:
        lines = f.readlines()
    for line in lines[:2000]:
        if "NAtoms" in line:
            #print(line)
            num_atoms = int(re.findall(r"[-+]?\d*\.\d+|\d+", line)[0])
    for idx, line in enumerate(lines):
        if "Mulliken charges and spin densities" in line:
            #print(line)
            rel_index = idx+2 
            break
    #print(rel_index)
    #print(num_atoms)
    #print(num_atoms)
    #print(idx)
    spin_dens = []
    charges = []
    for line in lines[idx+2:idx+2+num_atoms]:
        #print(line)
        spin_dens.append(float(re.findall(r"[-+]?\d*\.\d+|\d+", line)[-1]))
        charges.append(float(re.findall(r"[-+]?\d*\.\d+|\d+", line)[-2]))

    return structure, spin_dens, charges

def get_h_bond_dist(log):
    structure = io.read(log, format='gaussian-out')
    positions = structure.get_positions()
    origin = positions[0]
    distances = []
    for xyz in positions:
        distances.append(np.sqrt((xyz[0]-origin[0])**2+(xyz[1]-origin[1])**2+(xyz[2]-origin[2])**2))
    
    nearest_neighbours = np.argpartition(distances, 6)
    nn = [x for x in nearest_neighbours[:6+1] if x != 0]
    atomic_nums = structure.get_atomic_numbers()
    
    for nn_index in nn:
        if atomic_nums[nn_index]==8:
            o_origin = positions[nn_index]
            o_distances = []
            for xyz in positions:
                o_distances.append(np.sqrt((xyz[0]-o_origin[0])**2+(xyz[1]-o_origin[1])**2+(xyz[2]-o_origin[2])**2))
            o_nearest_neighbours = np.argpartition(o_distances, 2)
            nn_o = [x for x in o_nearest_neighbours[:2+1] if x != nn_index]
            for second_nn_index in nn_o:
                if atomic_nums[second_nn_index]==8:
                    first_o_idx = nn_index
                    second_o_idx = second_nn_index
                    print(second_o_idx)
    
    origin = positions[second_o_idx+1]
    distances = []
    for xyz in positions:
        distances.append(np.sqrt((xyz[0]-origin[0])**2+(xyz[1]-origin[1])**2+(xyz[2]-origin[2])**2))
    nearest_to_h_index = np.argpartition(distances, 3)
    nearest_to_h_index = [x for x in nearest_neighbours[:3+1] if x != second_o_idx+1]
    for idx in nearest_to_h_index:
        if atomic_nums[idx] in [7, 8] and idx != second_o_idx:
            return distances[idx]

# %%
cat_to_ooh_oo_colinearity = defaultdict(float)
cat_to_ooh_oo_chg = defaultdict(float)

cat_to_ooh_metal_spin_ratio = defaultdict(float)
metal_spin_d = defaultdict(float)
is_ferro = defaultdict(bool)
o_o_ratio = defaultdict(float)
for l in logs:
#for l in ['/home/michael/ht_scaling_results/Mn_hexa_1/OOH/tpssh-Mn-25-OOH-HS-freq.log']:
    structure, spin_d, charges = get_spin_dens(l)
    distances = []
    positions = structure.get_positions()
    atomic_nums = structure.get_atomic_numbers()

    origin = positions[np.argmax(atomic_nums)]
    for xyz in positions:
        distances.append(np.sqrt((xyz[0]-origin[0])**2+(xyz[1]-origin[1])**2+(xyz[2]-origin[2])**2))
    
    nearest_neighbours = np.argpartition(distances, 6)
    nn = [x for x in nearest_neighbours[:6+1] if x != np.argmax(atomic_nums)]
    
    stop = False
    for nn_index in nn:
        if atomic_nums[nn_index]==8 and not stop:
            o_origin = positions[nn_index]
            o_distances = []
            for xyz in positions:
                o_distances.append(np.sqrt((xyz[0]-o_origin[0])**2+(xyz[1]-o_origin[1])**2+(xyz[2]-o_origin[2])**2))
            o_nearest_neighbours = np.argpartition(o_distances, 3)
            nn_o = [x for x in o_nearest_neighbours[:3+1] if x != nn_index]
            for second_nn_index in nn_o:
                if atomic_nums[second_nn_index]==8:
                    first_o_idx = nn_index
                    second_o_idx = second_nn_index
                    second_o_orig = positions[second_o_idx]
                    second_o_dists = []
                    for xyz in positions:
                        second_o_dists.append(np.sqrt((xyz[0]-second_o_orig[0])**2+(xyz[1]-second_o_orig[1])**2+(xyz[2]-second_o_orig[2])**2))
                    second_o_nearest_neighbours = np.argpartition(second_o_dists, 3)
                    second_nn_o = [x for x in second_o_nearest_neighbours[:3+1] if x != nn_index]
                    for closest_to_nn_o in second_nn_o:
                        if atomic_nums[closest_to_nn_o]==1:
                            stop = True

    if "Co_hexa_4" in l or "Ni_oct_desorbed_4_" in l or "Ni_3a1_1" in l:
        continue
    print(l)
    print(spin_d[first_o_idx]*spin_d[second_o_idx])
    if spin_d[first_o_idx]>0 and spin_d[second_o_idx]>0 and spin_d[0]<0:
        is_ferro[l.split("/")[4]] = False
    elif spin_d[first_o_idx]<0 and spin_d[second_o_idx]<0 and spin_d[0]>0:
        is_ferro[l.split("/")[4]] = False
    else:
        is_ferro[l.split("/")[4]] = True
    
    cat_to_ooh_oo_colinearity[l.split("/")[4]] = spin_d[first_o_idx]*spin_d[second_o_idx]
    cat_to_ooh_oo_chg[l.split("/")[4]] = charges[first_o_idx]*charges[second_o_idx]

    metal_spin_d[l.split("/")[4]] = spin_d[np.argmax(atomic_nums)]
    if abs(spin_d[first_o_idx])>0.05 and abs(spin_d[second_o_idx])>0.05:
        o_o_ratio[l.split("/")[4]] = spin_d[first_o_idx]/spin_d[second_o_idx]
    #cat_to_ooh_oo_colinearity[l.split("/")[4]] = colinearity_oxygens/spin_d[0]

cat_to_oh_spin = defaultdict(float)
metal_spin_d_oh = defaultdict(float)
for l in oh_logs:
#for l in ['/home/michael/ht_scaling_results/Mn_hexa_1/OOH/tpssh-Mn-25-OOH-HS-freq.log']:
    structure, spin_d, charges = get_spin_dens(l)
    distances = []
    positions = structure.get_positions()
    atomic_nums = structure.get_atomic_numbers()

    origin = positions[np.argmax(atomic_nums)]
    for xyz in positions:
        distances.append(np.sqrt((xyz[0]-origin[0])**2+(xyz[1]-origin[1])**2+(xyz[2]-origin[2])**2))
    
    nearest_neighbours = np.argpartition(distances, 6)
    nn = [x for x in nearest_neighbours[:6+1] if x != np.argmax(atomic_nums)]
    
    for nn_index in nn:
        if atomic_nums[nn_index]==8:
            o_origin = positions[nn_index]
            o_distances = []
            for xyz in positions:
                o_distances.append(np.sqrt((xyz[0]-o_origin[0])**2+(xyz[1]-o_origin[1])**2+(xyz[2]-o_origin[2])**2))
            o_nearest_neighbours = np.argpartition(o_distances, 3)
            nn_o = [x for x in o_nearest_neighbours[:3+1] if x != nn_index]
            for second_nn_index in nn_o:
                if atomic_nums[second_nn_index]==1:
                    first_o_idx = nn_index
                    second_o_idx = second_nn_index

    if "Co_hexa_4" in l or "Ni_oct_desorbed_4_" in l or "Ni_3a1_1" in l:
        continue
    
    cat_to_oh_spin[l.split("/")[4]] = spin_d[first_o_idx]
    metal_spin_d_oh[l.split("/")[4]] = spin_d[np.argmax(atomic_nums)]
# Out:
# /home/michael/ht_scaling_results/Fe_31a_17/OOH/HS/Fe_31a_17_OOH_HS.log
# 0.04313273964
# /home/michael/ht_scaling_results/Co_31a_23/OOH/LS/Co_31a_23_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Mn_32a_35/OOH/HS/Mn_32a_35_OOH_HS.log
# 0.021888658076
# /home/michael/ht_scaling_results/Ru_32a_34/OOH/LS/Ru_32a_34_OOH_LSb.log
# 0.018064152099000003
# /home/michael/ht_scaling_results/Mn_31a_23/OOH/HS/Mn_31a_23_OOH_HS.log
# 0.01365433797
# /home/michael/ht_scaling_results/Fe_3a1_5_/OOH/LS/Fe_3a1_5_OOH_LS.log
# 0.045438844032
# /home/michael/ht_scaling_results/Ni_3a1_5_/OOH/LS/Ni_3a1_5_OOH_LS.log
# 0.166629645075
# /home/michael/ht_scaling_results/Cr_3a1_28/OOH/HS/Cr_3a1_28_OOH_HS.log
# 0.003295309536
# /home/michael/ht_scaling_results/Ru_3a1_1_/OOH/LS/Ru_3a1_1_OOH_LS.log
# 0.039063512429999996
# /home/michael/ht_scaling_results/Fe_3a1_22/OOH/HS/Fe_3a1_22_OOH_HS.log
# 0.069697116561
# /home/michael/ht_scaling_results/Co_penta_4/OOH/Co_penta_4_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ni_3a1_24/OOH/LS/Ni_3a1_24_OOH_LS.log
# 0.20855540862
# /home/michael/ht_scaling_results/Co_3a1_2_/OOH/LS/Co_3a1_2_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_31a_30/OOH/LS/Co_31a_30_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Cr_3a1_25/OOH/HS/Cr_3a1_25_OOH_HSb.log
# -6.9342609e-05
# /home/michael/ht_scaling_results/Fe_32a_35/OOH/HS/Fe_32a_35_OOH_HSb.log
# 0.039988186056
# /home/michael/ht_scaling_results/Ru_penta_5/OOH/Ru_penta_5_OOH_LS.log
# 0.0037452904770000003
# /home/michael/ht_scaling_results/Co_31a_14/OOH/LS/Co_31a_14_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Cr_31a_28/OOH/HS/Cr_31a_28_OOH_HS.log
# 0.0028706125829999997
# /home/michael/ht_scaling_results/Co_32a_35/OOH/LS/Co_32a_35_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_3a1_24/OOH/LS/Co_3a1_24_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Fe_penta_2/OOH/Fe_penta_2_OOH_HS.log
# 0.044171766769999996
# /home/michael/ht_scaling_results/Mn_31a_18/OOH/HS/Mn_31a_18_OOH_HS.log
# 0.007096972872
# /home/michael/ht_scaling_results/Fe_31a_20/OOH/LS/Fe_31a_20_OOH_LS.log
# 0.06527405287
# /home/michael/ht_scaling_results/Co_31a_6_/OOH/LS/Co_31a_6_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_oct_desorbed_2_/OOH/LS/Co_oct_desorbed_2_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Mn_hexa_4/OOH/tpssh-Co-16-OOH-Mn_is_hs.log
# 0.000607379193
# /home/michael/ht_scaling_results/Co_32a_31/OOH/LS/Co_32a_31_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_15/OOH/LS/Ru_31a_15_OOH_LS.log
# 0.011262125928
# /home/michael/ht_scaling_results/Ni_32a_34/OOH/HS/Ni_32a_34_OOH_HS.log
# 0.21278640573
# /home/michael/ht_scaling_results/Co_3a1_3_/OOH/LS/Co_3a1_3_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ni_oct_desorbed_5_/OOH/LS/Ni_oct_desorbed_5_OOH_LS.log
# 0.15050632968
# /home/michael/ht_scaling_results/Mn_31a_17/OOH/HS/Mn_31a_17_OOH_HS.log
# 0.00929804514
# /home/michael/ht_scaling_results/Ni_3a1_4_/OOH/LS/Ni_3a1_4_OOH_LS.log
# 0.165635785894
# /home/michael/ht_scaling_results/Ru_31a_13/OOH/LS/Ru_31a_13_OOH_LS.log
# 0.00403837665
# /home/michael/ht_scaling_results/Ru_3a1_27/OOH/LS/Ru_3a1_27_OOH_LS.log
# 0.02497028238
# /home/michael/ht_scaling_results/Ru_32a_31/OOH/LS/Ru_32a_31_OOH_LS.log
# 0.055133852515
# /home/michael/ht_scaling_results/Cr_3a1_20/OOH/HS/Cr_3a1_20_OOH_HS.log
# 0.0039746270080000005
# /home/michael/ht_scaling_results/Fe_3a1_20/OOH/HS/Fe_3a1_20_OOH_HS.log
# 0.074698117956
# /home/michael/ht_scaling_results/Fe_41a_2_/OOH/LS/Fe_41a_2_OOH_LS.log
# 0.005269741257
# /home/michael/ht_scaling_results/Fe_3a1_26/OOH/HS/Fe_3a1_26_OOH_HS-retry.log
# 0.007942893119999999
# /home/michael/ht_scaling_results/Ni_penta_1/OOH/Ni_penta_1_OOH-LS.log
# 0.15472796701
# /home/michael/ht_scaling_results/Ni_hexa_1/OOH/LS/Ni_hexa_1_OOH_LS.log
# 0.09110831067000001
# /home/michael/ht_scaling_results/Fe_penta_1/OOH/Fe_penta_1_OOH_HS.log
# 0.03133846917
# /home/michael/ht_scaling_results/Mn_31a_25/OOH/HS/Mn_31a_25_OOH_HS.log
# 0.040614853815000004
# /home/michael/ht_scaling_results/Mn_penta_3/OOH/Mn_penta_OOH_HS.log
# 0.007336824405
# /home/michael/ht_scaling_results/Ru_3a1_22/OOH/LS/Ru_3a1_22_OOH_LS.log
# 0.0236132448
# /home/michael/ht_scaling_results/Fe_3a1_29/OOH/HS/Fe_3a1_29_OOH_HS.log
# 0.049069899522000006
# /home/michael/ht_scaling_results/Ru_31a_22/OOH/LS/Ru_31a_22_OOH_LS.log
# 0.028600832164
# /home/michael/ht_scaling_results/Ru_31a_20/OOH/LS/Ru_31a_20_OOH_LS.log
# 0.042441561092
# /home/michael/ht_scaling_results/Co_3a1_30/OOH/LS/Co_3a1_30_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_penta_3/OOH/Ru_penta_3_OOH_LS.log
# 0.022614018968000003
# /home/michael/ht_scaling_results/Ru_3a1_28/OOH/LS/Ru_3a1_28_OOH_LS.log
# 0.02098599432
# /home/michael/ht_scaling_results/Co_31a_15/OOH/LS/Co_31a_15_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_3a1_16/OOH/LS/Ru_3a1_16_OOH_LS.log
# 0.007718492308
# /home/michael/ht_scaling_results/Cr_31a_24/OOH/HS/Cr_31a_24_OOH_HS.log
# 0.003394276928
# /home/michael/ht_scaling_results/Ru_oct_desorbed_4_/OOH/LS/Ru_oct_desorbed_4_OOH_LS.log
# 0.030310780352
# /home/michael/ht_scaling_results/Cr_31a_5_/OOH/HS/Cr_31a_5_OOH_HS.log
# 0.004974663168
# /home/michael/ht_scaling_results/Ni_31a_2_/OOH/LS/Ni_31a_2_OOH_LS.log
# 0.166333826656
# /home/michael/ht_scaling_results/Co_oct_desorbed_4_/OOH/LS/Co_oct_desorbed_4_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Cr_3a1_26/OOH/HS/Cr_3a1_26_OOH_HS.log
# 0.0031960639199999996
# /home/michael/ht_scaling_results/Ru_penta_1/OOH/LS/Ru_penta_1_OOH_LS.log
# 0.022190159653000002
# /home/michael/ht_scaling_results/Co_oct_desorbed_6_/OOH/LS/Co_oct_desorbed_6_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_oct_desorbed_5_/OOH/LS/Co_oct_desorbed_5_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Mn_pbp_1_/OOH/HS/Mn_pbp_1_OOH_HS.log
# 0.001324982892
# /home/michael/ht_scaling_results/Fe_3a1_17/OOH/HS/Fe_3a1_17_OOH_HS.log
# 0.01974279744
# /home/michael/ht_scaling_results/Cr_oct_desorbed_4_/OOH/HS/Cr_oct_desorbed_4_OOH_HS.log
# 0.004493319912
# /home/michael/ht_scaling_results/Fe_hexa_4/OOH/tpssh-Co-16-OOH-LS-Fe.log
# 9.7031987e-05
# /home/michael/ht_scaling_results/Ru_oct_desorbed_5_/OOH/LS/Ru_oct_desorbed_5_OOH_LS.log
# 0.019626687872
# /home/michael/ht_scaling_results/Ru_31a_17/OOH/LS/Ru_31a_17_OOH_LS.log
# 0.005979062429999999
# /home/michael/ht_scaling_results/Co_3a1_29/OOH/LS/Co_3a1_29_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Fe_3a1_1_/OOH/LS/Fe_3a1_1_OOH_LS.log
# 0.07583203022200001
# /home/michael/ht_scaling_results/Cr_3a1_21/OOH/HS/Cr_3a1_21_OOH_HS.log
# 0.0036910920880000005
# /home/michael/ht_scaling_results/Co_3a1_10/OOH/LS/Co_3a1_10_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_3a1_19/OOH/LS/Co_3a1_19_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_3a1_23/OOH/LS/Ru_3a1_23_OOH_LS.log
# 0.02360023104
# /home/michael/ht_scaling_results/Ni_3a1_29/OOH/LS/Ni_3a1_29_OOH_LS.log
# 0.16254613668
# /home/michael/ht_scaling_results/Ru_41a_2_/OOH/LS/Ru_41a_2_OOH_LS.log
# 0.011648774898000001
# /home/michael/ht_scaling_results/Ru_penta_4/OOH/Ru_penta_4_OOH_LS.log
# -0.001133369721
# /home/michael/ht_scaling_results/Ru_31a_10/OOH/LS/Ru_31a_10_OOH_LS.log
# 0.008198730732
# /home/michael/ht_scaling_results/Mn_31a_5_/OOH/HS/Mn_31a_5_OOH_HS.log
# 0.021052662137999997
# /home/michael/ht_scaling_results/Fe_31a_4_/OOH/LS/Fe_31a_4_OOH_LS.log
# 0.04588861449
# /home/michael/ht_scaling_results/Ni_3a1_23/OOH/LS/Ni_3a1_23_OOH_LS.log
# 0.166454467641
# /home/michael/ht_scaling_results/Ru_32a_32/OOH/LS/Ru_32a_32_OOH_LS.log
# 0.015230807620999999
# /home/michael/ht_scaling_results/Mn_oct_desorbed_5_/OOH/HS/Mn_oct_desorbed_5_OOH_HS.log
# 0.01056631975
# /home/michael/ht_scaling_results/Co_31a_17/OOH/LS/Co_31a_17_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_3a1_24/OOH/LS/Ru_3a1_24_OOH_LS.log
# 0.018179956768
# /home/michael/ht_scaling_results/Co_41a_1_/OOH/LS/Co_41a_1_OOH_LS-fromb4.log
# 0.0
# /home/michael/ht_scaling_results/Mn_hexa_1/OOH/tpssh-Mn-25-OOH-HS-freq.log
# 0.001633283784
# /home/michael/ht_scaling_results/Ni_31a_28/OOH/LS/Ni_31a_28_OOH_LS.log
# 0.161389581744
# /home/michael/ht_scaling_results/Ni_31a_19/OOH/LS/Ni_31a_19_OOH_LS.log
# 0.191645417535
# /home/michael/ht_scaling_results/Co_oct_desorbed_3_/OOH/LS/Co_oct_desorbed_3_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Cr_hexa_1/OOH/Cr_hexa_1-OOH.log
# 0.0016646080139999999
# /home/michael/ht_scaling_results/Ni_31a_20/OOH/LS/Ni_31a_20_OOH_LS.log
# 0.169261164912
# /home/michael/ht_scaling_results/Mn_penta_2/OOH/Mn_penta_2_OOH_HS.log
# 0.002547867159
# /home/michael/ht_scaling_results/Cr_oct_desorbed_1_/OOH/HS/Cr_oct_desorbed_1_OOH_HS.log
# 0.006794150061
# /home/michael/ht_scaling_results/Co_31a_5_/OOH/LS/Co_31a_5_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ni_3a1_3_/OOH/LS/forw/Ni_3a1_3_OOH_LS-f_3e-1.log
# 0.21051654541700002
# /home/michael/ht_scaling_results/Co_32a_32/OOH/LS/Co_32a_32_OOH_LSb.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_2_/OOH/LS/Ru_31a_2_OOH_LS.log
# 0.057831496940000005
# /home/michael/ht_scaling_results/Ni_oct_desorbed_2_/OOH/LS/Ni_oct_desorbed_2_OOH_LS.log
# 0.0763910381
# /home/michael/ht_scaling_results/Ru_3a1_20/OOH/LS/Ru_3a1_20_OOH_LS.log
# 0.017285343649
# /home/michael/ht_scaling_results/Co_3a1_25/OOH/LS/Co_3a1_25_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_oct_desorbed_6_/OOH/LS/Ru_oct_desorbed_6_OOH_LS.log
# 0.018834204293999998
# /home/michael/ht_scaling_results/Mn_31a_15/OOH/HS/Mn_31a_15_OOH_HS.log
# 0.010741271310000002
# /home/michael/ht_scaling_results/Ni_41a_1_/OOH/LS/Ni_41a_1_OOH_LS-cartesian.log
# 0.208135032496
# /home/michael/ht_scaling_results/Fe_31a_26/OOH/HS/Fe_31a_26_OOH_HS-continue.log
# 0.03713221699
# /home/michael/ht_scaling_results/Mn_41a_2_/OOH/HS/Mn_41a_2_OOH_HS-cartesian.log
# 0.001623439625
# /home/michael/ht_scaling_results/Fe_3a1_28/OOH/HS/Fe_3a1_28_OOH_HS.log
# 0.050357633977
# /home/michael/ht_scaling_results/Co_32a_33/OOH/LS/Co_32a_33_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_hexa_1/OOH/LS/Ru_hexa_1_OOH-LS.log
# 0.030588487632000002
# /home/michael/ht_scaling_results/Ru_oct_desorbed_2_/OOH/LS/Ru_oct_desorbed_2_OOH_LS.log
# 0.054447315864
# /home/michael/ht_scaling_results/Cr_oct_desorbed_2_/OOH/HS/Cr_oct_desorbed_2_OOH_HS.log
# 0.00535389296
# /home/michael/ht_scaling_results/Co_hexa_1/OOH/tpssh-Mn-10-OOH-Co_is_ls.log
# 0.0
# /home/michael/ht_scaling_results/Cr_32a_32/OOH/HS/Cr_32a_32_OOH_HS.log
# 0.00226351461
# /home/michael/ht_scaling_results/Ru_31a_18/OOH/LS/Ru_31a_18_OOH_LS.log
# 0.011861998826
# /home/michael/ht_scaling_results/Ru_oct_desorbed_1_/OOH/LS/Ru_oct_desorbed_1_OOH_LS.log
# 0.04040371168
# /home/michael/ht_scaling_results/Ni_3a1_26/OOH/LS/Ni_3a1_26_OOH_LS.log
# 0.16647296727599997
# /home/michael/ht_scaling_results/Ru_3a1_10/OOH/LS/Ru_3a1_10_OOH_LS.log
# 0.008642630568
# /home/michael/ht_scaling_results/Ru_3a1_5_/OOH/LS/Ru_3a1_5_OOH_LS.log
# 0.030888339124999997
# /home/michael/ht_scaling_results/Ru_oct_desorbed_3_/OOH/LS/Ru_oct_desorbed_3_OOH_LS.log
# 0.014378400995999999
# /home/michael/ht_scaling_results/Fe_31a_23/OOH/LS/Fe_31a_23_OOH_LS.log
# 0.030314315916000003
# /home/michael/ht_scaling_results/Fe_3a1_19/OOH/HS/Fe_3a1_19_OOH_HSb.log
# 0.04112968798
# /home/michael/ht_scaling_results/Co_3a1_5_/OOH/LS/Co_3a1_5_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_31a_19/OOH/LS/Co_31a_19_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Mn_32a_34/OOH/HS/Mn_32a_34_OOH_HS.log
# 0.017279103717
# /home/michael/ht_scaling_results/Fe_penta_5/OOH/Fe_penta_5_OOH_HS.log
# 0.0020688689839999997
# /home/michael/ht_scaling_results/Ni_32a_35/OOH/HS/Ni_32a_35_OOH_HS.log
# 0.21032519005199998
# /home/michael/ht_scaling_results/Ru_31a_11/OOH/LS/Ru_31a_11_OOH_LS.log
# 0.013070390897
# /home/michael/ht_scaling_results/Cr_penta_2/OOH/Cr_penta_2_OOH_HS.log
# -0.00013649567700000002
# /home/michael/ht_scaling_results/Cr_penta_4/OOH/Cr_penta_4_OOH_HS.log
# 0.001816463026
# /home/michael/ht_scaling_results/Cr_41a_3_/OOH/HS/Cr_41a_3_OOH_HS-cartesian.log
# -9.4159534e-05
# /home/michael/ht_scaling_results/Ru_32a_35/OOH/LS/Ru_32a_35_OOH_LS.log
# 0.031325094066
# /home/michael/ht_scaling_results/Cr_3a1_30/OOH/HS/forw/Cr_3a1_30_OOH_HS-f_3e-1.log
# -8.213150000000001e-07
# /home/michael/ht_scaling_results/Ni_3a1_30/OOH/LS/Ni_3a1_30_OOH_LS.log
# 0.16314073592599998
# /home/michael/ht_scaling_results/Ru_3a1_30/OOH/LS/Ru_3a1_30_OOH_LS.log
# 0.019910236518000002
# /home/michael/ht_scaling_results/Ru_31a_6_/OOH/LS/Ru_31a_6_OOH_LS.log
# 0.04852610886
# /home/michael/ht_scaling_results/Ru_3a1_11/OOH/LS/Ru_3a1_11_OOH_LS.log
# 0.005640417402
# /home/michael/ht_scaling_results/Co_41a_2_/OOH/LS/Co_41a_2_OOH_LS-cartesian.log
# 0.0
# /home/michael/ht_scaling_results/Co_31a_3_/OOH/LS/Co_31a_3_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_29/OOH/LS/Ru_31a_29_OOH_LS.log
# 0.027280922284
# /home/michael/ht_scaling_results/Ru_31a_8_/OOH/LS/Ru_31a_8_OOH_LS.log
# 0.011822642707
# /home/michael/ht_scaling_results/Ni_32a_31/OOH/HS/forw/Ni_32a_31_OOH_HSb-f_3e-1.log
# 0.23914312015999997
# /home/michael/ht_scaling_results/Mn_3a1_20/OOH/HS/Mn_3a1_20_OOH_HS.log
# 0.015774556915
# /home/michael/ht_scaling_results/Co_32a_34/OOH/LS/Co_32a_34_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_23/OOH/LS/Ru_31a_23_OOH_LS.log
# 0.030923735310000002
# /home/michael/ht_scaling_results/Ru_31a_12/OOH/LS/Ru_31a_12_OOH_LS.log
# 0.008368111232
# /home/michael/ht_scaling_results/Co_3a1_1_/OOH/LS/Co_3a1_1_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_3a1_29/OOH/LS/Ru_3a1_29_OOH_LS.log
# 0.019671450312
# /home/michael/ht_scaling_results/Mn_3a1_28/OOH/HS/Mn_3a1_28_OOH_HS.log
# 0.011441438368
# /home/michael/ht_scaling_results/Ru_31a_7_/OOH/LS/Ru_31a_7_OOH_LS.log
# 0.01301791095
# /home/michael/ht_scaling_results/Ru_3a1_2_/OOH/LS/Ru_3a1_2_OOH_LS.log
# 0.028628602592
# /home/michael/ht_scaling_results/Fe_oct_desorbed_2_/OOH/HS/Fe_oct_desorbed_2_OOH_HS.log
# 0.040085510984999996
# /home/michael/ht_scaling_results/Co_31a_9_/OOH/LS/Co_31a_9_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_3a1_20/OOH/LS/Co_3a1_20_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_penta_1/OOH/Co_penta_1_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_14/OOH/LS/Ru_31a_14_OOH_LS.log
# 0.006491925828
# /home/michael/ht_scaling_results/Fe_hexa_1/OOH/LS/tpssh-Mn-10-OOH-Fe_LS.log
# 0.028891066176000003
# /home/michael/ht_scaling_results/Mn_3a1_26/OOH/HS/Mn_3a1_26_OOH_HS.log
# 0.006071342288
# /home/michael/ht_scaling_results/Cr_oct_desorbed_5_/OOH/HS/Cr_oct_desorbed_5_OOH_HS.log
# 0.004348389177
# /home/michael/ht_scaling_results/Ru_31a_30/OOH/LS/Ru_31a_30_OOH_LS.log
# 0.0276587673
# /home/michael/ht_scaling_results/Cr_3a1_23/OOH/HS/Cr_3a1_23_OOH_HS.log
# 0.0034986031349999998
# /home/michael/ht_scaling_results/Cr_penta_1/OOH/Cr_penta_1_OOH_HS.log
# 0.000826036943
# /home/michael/ht_scaling_results/Ni_3a1_28/OOH/LS/Ni_3a1_28_OOH_LS.log
# 0.16219279712
# /home/michael/ht_scaling_results/Ni_31a_30/OOH/LS/Ni_31a_30_OOH_LS.log
# 0.163836251705
# /home/michael/ht_scaling_results/Ni_31a_4_/OOH/LS/Ni_31a_4_OOH_LS.log
# 0.167493924232
# /home/michael/ht_scaling_results/Mn_31a_26/OOH/HS/Mn_31a_26_OOH_HS.log
# 0.005068595952000001
# /home/michael/ht_scaling_results/Co_31a_20/OOH/LS/Co_31a_20_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_19/OOH/LS/Ru_31a_19_OOH_LS.log
# 0.046992933542
# /home/michael/ht_scaling_results/Ni_31a_24/OOH/LS/Ni_31a_24_OOH_LS.log
# 0.168248881332
# /home/michael/ht_scaling_results/Cr_oct_desorbed_6_/OOH/HS/Cr_oct_desorbed_6_OOH_HS.log
# 0.0037792218160000004
# /home/michael/ht_scaling_results/Ni_3a1_25/OOH/LS/Ni_3a1_25_OOH_LS.log
# 0.16216870554
# /home/michael/ht_scaling_results/Co_31a_24/OOH/LS/Co_31a_24_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Fe_31a_29/OOH/HS/Fe_31a_29_OOH_HS.log
# 0.06882985742499999
# /home/michael/ht_scaling_results/Ru_31a_3_/OOH/LS/Ru_31a_3_OOH_LS.log
# 0.049216901311999996
# /home/michael/ht_scaling_results/Cr_3a1_29/OOH/HS/Cr_3a1_29_OOH_HS.log
# 0.0032025327479999997
# /home/michael/ht_scaling_results/Cr_31a_19/OOH/HS/Cr_31a_19_OOH_HS.log
# 0.002664615744
# /home/michael/ht_scaling_results/Ru_31a_9_/OOH/LS/Ru_31a_9_OOH_LS.log
# 0.010581726437
# /home/michael/ht_scaling_results/Ru_31a_27/OOH/LS/Ru_31a_27_OOH_LS.log
# 0.035736041090999995
# /home/michael/ht_scaling_results/Fe_31a_18/OOH/HS/Fe_31a_18_OOH_HS.log
# 0.036790582092
# /home/michael/ht_scaling_results/Co_3a1_27/OOH/LS/Co_3a1_27_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_3a1_13/OOH/LS/Ru_3a1_13_OOH_LS.log
# 0.011828064081
# /home/michael/ht_scaling_results/Ni_3a1_2_/OOH/LS/Ni_3a1_2_OOH_LS.log
# 0.16558017073
# /home/michael/ht_scaling_results/Ru_3a1_26/OOH/LS/Ru_3a1_26_OOH_LS.log
# 0.023573171610999998
# /home/michael/ht_scaling_results/Cr_penta_3/OOH/Cr_penta_3_OOH_HS.log
# 0.007947760251
# /home/michael/ht_scaling_results/Ru_3a1_14/OOH/LS/Ru_3a1_14_OOH_LS.log
# 0.01611085966
# /home/michael/ht_scaling_results/Ru_31a_24/OOH/LS/Ru_31a_24_OOH_LS.log
# 0.035167708828
# /home/michael/ht_scaling_results/Cr_32a_31/OOH/HS/Cr_32a_31_OOH_HSb.log
# 5.87988e-07
# /home/michael/ht_scaling_results/Ni_31a_13/OOH/LS/Ni_31a_13_OOH_LS.log
# 0.18748476626299998
# /home/michael/ht_scaling_results/Ru_31a_4_/OOH/LS/Ru_31a_4_OOH_LS.log
# 0.049323738224
# /home/michael/ht_scaling_results/Ru_3a1_4_/OOH/LS/Ru_3a1_4_OOH_LS.log
# 0.040762095761
# /home/michael/ht_scaling_results/Co_3a1_13/OOH/LS/Co_3a1_13_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_31a_26/OOH/LS/Co_31a_26_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_31a_5_/OOH/LS/Ru_31a_5_OOH_LS.log
# 0.048464865688
# /home/michael/ht_scaling_results/Ru_31a_28/OOH/LS/Ru_31a_28_OOH_LS.log
# 0.029097679918
# /home/michael/ht_scaling_results/Mn_oct_desorbed_3_/OOH/HS/Mn_oct_desorbed_3_OOH_HS.log
# 0.015178541154
# /home/michael/ht_scaling_results/Co_penta_2/OOH/Co_penta_2_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Cr_3a1_4_/OOH/HS/Cr_3a1_4_OOH_HS.log
# 0.004323097532
# /home/michael/ht_scaling_results/Co_31a_18/OOH/LS/Co_31a_18_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_3a1_26/OOH/LS/Co_3a1_26_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Co_3a1_22/OOH/LS/Co_3a1_22_OOH_LS.log
# 0.0
# /home/michael/ht_scaling_results/Ru_41a_3_/OOH/LS/Ru_41a_3_OOH_LS.log
# 0.001270725297
# /home/michael/ht_scaling_results/Mn_32a_31/OOH/HS/Mn_32a_31_OOH_HS-fromOH.log
# 0.07850980649700001
# /home/michael/ht_scaling_results/Ru_31a_16/OOH/LS/Ru_31a_16_OOH_LS.log
# 0.006713856
# /home/michael/ht_scaling_results/Co_oct_desorbed_1_/OOH/LS/Co_oct_desorbed_1_OOH_LS.log
# 0.0

# %%
valid_convergers = pickle.load(open("well_behaved_cats.p", "rb"))

valid_names = list(set([x.split("/")[4] for x in valid_convergers]))
print(len(valid_names))
data = pickle.load(open("/home/michael/PycharmProjects/gaussian_job_manage/catalyst_data.p", 'rb'))

catnames = []
oh_values = []
ooh_values = []

for name in data:
    if "pbp" in name or name not in valid_names and "hexa" not in name:
        continue
    catnames.append(name)
    oh_values.append(data[name][0])
    ooh_values.append(data[name][1])
    
def deviation_from_scaling(oh_val, ooh_val):
    return ooh_val - 0.9*oh_val - 3.4

name2deviation = defaultdict(float)
for oh, ooh, name in zip(oh_values, ooh_values, catnames):
    name2deviation[name] = deviation_from_scaling(oh, ooh)
# Out:
# 218

# %%
print(catnames[np.argmax(ooh_values)])
# Out:
# Ni_31a_19

# %%
colinearity = []
deviation = []
metal_s = []
ferro_or_not = []
charges = []
oh_spin = []
# TO DO: Compare differences vs. OH intermediate?
for val in name2deviation:
    if val in cat_to_ooh_oo_colinearity:
        colinearity.append(cat_to_ooh_oo_colinearity[val])
        deviation.append(name2deviation[val])
        metal_s.append(metal_spin_d[val])
        ferro_or_not.append(int(is_ferro[val]))
        charges.append(cat_to_ooh_oo_chg[val])
        oh_spin.append(cat_to_oh_spin[val])
        if "Ni" in val and cat_to_ooh_oo_colinearity[val]<0.1:
        #if cat_to_ooh_oo_colinearity[val]>0.1:
            print(val)
            print(name2deviation[val])
            print(metal_spin_d[val])
            print(cat_to_ooh_oo_colinearity[val])
        #if name2deviation[val]<-.4:
        #    print(val)
        #    print(cat_to_ooh_oo_colinearity[val])
        #    print(name2deviation[val])
         #   print(metal_spin_d[val])
#name2deviation
# Out:
# Ni_hexa_1
# -0.03508856267357663
# 0.349843
# 0.09110831067000001
# Ni_oct_desorbed_2_
# 0.07530895789779857
# 1.258565
# 0.0763910381

# %%
plt.plot(colinearity, deviation, 'ro')
plt.axhline(0)

# %%
fig = plt.figure(figsize=(9,8))
#ax = plt.axes(projection='3d')
plt.scatter(colinearity, metal_s, c=deviation, cmap='seismic', alpha=0.5,edgecolors='k');
#ax.view_init(60, 15)

plt.xlabel(r"$\lambda$", fontsize=16)
plt.ylabel(r"$\rho_{metal}$", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.zlabel("Deviation from scaling")
plt.colorbar()
#plt.savefig("3d_30.pdf")
plt.clim(-.4,.4)

# %%
np.min(colinearity)
# Out:
# -0.001133369721

# %%
fig = plt.figure(figsize=(9,8))
#ax = plt.axes(projection='3d')
plt.scatter(colinearity, metal_s, c=deviation, alpha=0.1, 
            vmax=0.4, vmin=-0.4, cmap='seismic', markeredgecolor='k')#, cmap='jet');
#ax.view_init(60, 15)

plt.xlabel(r"$\lambda$", fontsize=16)
plt.ylabel(r"$\rho_{metal}$", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.zlabel("Deviation from scaling")
plt.colorbar()
plt.savefig("3d_30.pdf")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9ccfac7f14fb> in <module>
#       2 #ax = plt.axes(projection='3d')
#       3 plt.scatter(colinearity, metal_s, c=deviation, alpha=0.1,
# ----> 4             vmax=0.4, vmin=-0.4, cmap='seismic', markeredgecolor='k')#, cmap='jet');
#       5 #ax.view_init(60, 15)
#       6
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4499                 )
#    4500         collection.set_transform(mtransforms.IdentityTransform())
# -> 4501         collection.update(kwargs)
#    4502
#    4503         if colors is None:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'PathCollection' object has no property 'markeredgecolor'

# %%
fig = plt.figure(figsize=(9,8))
#ax = plt.axes(projection='3d')
plt.scatter(colinearity, oh_spin, c=deviation, cmap='seismic');
#ax.view_init(60, 15)

plt.xlabel("spin density(O*O)", fontsize=16)
plt.ylabel("spin density(metal)", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.zlabel("Deviation from scaling")
plt.colorbar()

# %%
# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(colinearity, metal_s, charges, c=deviation, cmap='seismic');
for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()
    plt.pause(.001)

# %%
colinearity = []
deviation = []
#metal_s = []
ratio = []
for val in name2deviation:
    if val in cat_to_ooh_oo_colinearity and val in o_o_ratio:
        colinearity.append(cat_to_ooh_oo_colinearity[val])
        deviation.append(name2deviation[val])
        ratio.append(o_o_ratio[val])

# %%
h_bond_distances = defaultdict()

for l in logs:
    print(l)
    if "Ni_oct_desorbed_4_" in l or "Ni_3a1_1" in l or "hexa" in l:
        continue
    h_bond_distances[l.split("/")[4]] = get_h_bond_dist(l)

# %%
colinearity = []
deviation = []
metal_s = []
h_bond_dist = []
for val in name2deviation:
    if val in cat_to_ooh_oo_colinearity and val in h_bond_distances:
        colinearity.append(cat_to_ooh_oo_colinearity[val])
        deviation.append(name2deviation[val])
        h_bond_dist.append(h_bond_distances[val])
        metal_s.append(metal_spin_d[val])

# %%
fig = plt.figure(figsize=(9,8))
#ax = plt.axes(projection='3d')
plt.scatter(colinearity, h_bond_dist, c=deviation, cmap='seismic');
#ax.view_init(60, 15)

plt.xlabel("spin density(O*O)", fontsize=16)
plt.ylabel("spin density(metal)", fontsize=16)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
#plt.zlabel("Deviation from scaling")
plt.colorbar()

# %%
np.min(colinearity)
